# %%
from rolling_pin.conform_etl import ConformETL
# !rm -rf /home/ubuntu/build
src = '/home/ubuntu/lunchbox/docker/build.yaml'
etl = ConformETL.from_yaml(src)
etl.to_html(as_png=True)

# %%
etl.conform(groups=['base', 'tox'])
# !tree /home/ubuntu/build
# Out:
# /home/ubuntu/build
# ├── repo
# │   ├── LICENSE
# │   ├── README.md
# │   ├── flake8.ini
# │   ├── lunchbox
# │   │   ├── __init__.py
# │   │   ├── enforce.py
# │   │   ├── enforce_test.py
# │   │   ├── singleton.py
# │   │   ├── singleton_test.py
# │   │   ├── stopwatch.py
# │   │   ├── stopwatch_test.py
# │   │   ├── tools.py
# │   │   └── tools_test.py
# │   ├── mypy.ini
# │   ├── pdm.lock
# │   ├── pyproject.toml
# │   ├── pytest.ini
# │   └── tox.ini
# └── resources
#     └── foo.txt
#
# 3 directories, 18 files
