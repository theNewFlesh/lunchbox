# %%
from rolling_pin.conform_etl import ConformETL
# !rm -rf /home/ubuntu/build
src = '/home/ubuntu/lunchbox/docker/config/build.yaml'
etl = ConformETL.from_yaml(src)
etl.to_html(as_png=True)

# %%
etl.conform(groups=['base', 'prod'])
# !tree /home/ubuntu/build
# Out:
# /home/ubuntu/build
# └── repo
#     ├── LICENSE
#     ├── README.md
#     ├── flake8.ini
#     ├── lunchbox
#     │   ├── __init__.py
#     │   ├── enforce.py
#     │   ├── singleton.py
#     │   ├── stopwatch.py
#     │   └── tools.py
#     ├── mypy.ini
#     ├── pdm.lock
#     ├── pyproject.toml
#     ├── pytest.ini
#     └── tox.ini
#
# 2 directories, 13 files
