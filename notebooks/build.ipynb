# %%
from rolling_pin.conform_etl import ConformETL

src = '/home/ubuntu/lunchbox/docker/conform.yml'
etl = ConformETL.from_yaml(src)
etl.to_html(as_png=True)

# %%
etl.conform(groups=['base', 'test'])
# !tree /home/ubuntu/build
# Out:
# /home/ubuntu/build
# ├── repo
# │   ├── LICENSE
# │   ├── README.md
# │   ├── dev
# │   │   ├── pdm.lock
# │   │   └── pyproject.toml
# │   ├── flake8.ini
# │   ├── generate_pyproject.py
# │   ├── lunchbox
# │   │   ├── __init__.py
# │   │   ├── enforce.py
# │   │   ├── enforce_test.py
# │   │   ├── singleton.py
# │   │   ├── singleton_test.py
# │   │   ├── stopwatch.py
# │   │   ├── stopwatch_test.py
# │   │   ├── tools.py
# │   │   └── tools_test.py
# │   ├── mypy.ini
# │   ├── prod
# │   │   ├── pdm.lock
# │   │   └── pyproject.toml
# │   ├── pytest.ini
# │   └── tox.ini
# ├── resources
# │   └── foo.txt
# ├── temp
# └── tox
#     └── log
#
# 8 directories, 21 files
