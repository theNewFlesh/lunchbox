# %%
from rolling_pin.conform_etl import ConformETL

src = '/home/ubuntu/lunchbox/docker/conform.yml'
etl = ConformETL.from_yaml(src)
etl.to_html()
# Out:
# <object type="image/svg+xml" data="data:image/svg+xml;b'<?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.43.0 (0) --><!-- Title: %3 Pages: 1 --><svg width="1364pt" height="1016pt" viewBox="0.00 0.00 1364.00 1016.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1012)"><title>%3</title><polygon fill="#242424" stroke="transparent" points="-4,4 -4,-1012 1360,-1012 1360,4 -4,4"/><!-- root/tmp --><g id="node1" class="node"><title>root/tmp</title><polygon fill="#343434" stroke="#343434" points="54,-522 0,-522 0,-486 54,-486 54,-522"/><text text-anchor="middle" x="27" y="-500.3" font-family="Courier,monospace" font-size="14.00" fill="#de958e">tmp</text></g><!-- root/tmp/build --><g id="node2" class="node"><title>root/tmp/build</title><polygon fill="#343434" stroke="#343434" points="148,-522 90,-522 90,-486 148,-486 148,-522"/><text text-anchor="middle" x="119" y="-500.3" font-family="Courier,monospace" font-size="14.00" fill="#de958e">build</text></g><!-- root/tmp&#45;&gt;root/tmp/build --><g id="edge1" class="edge"><title>root/tmp&#45;&gt;root/tmp/build</title><path fill="none" stroke="#de958e" d="M54.03,-504C62,-504 70.95,-504 79.56,-504"/><polygon fill="#de958e" stroke="#de958e" points="79.82,-507.5 89.82,-504 79.82,-500.5 79.82,-507.5"/></g><!-- root/tmp/build/repo --><g id="node3" class="node"><title>root/tmp/build/repo</title><polygon fill="#343434" stroke="#343434" points="256.5,-738 202.5,-738 202.5,-702 256.5,-702 256.5,-738"/><text text-anchor="middle" x="229.5" y="-716.3" font-family="Courier,monospace" font-size="14.00" fill="#de958e">repo</text></g><!-- root/tmp/build&#45;&gt;root/tmp/build/repo --><g id="edge2" class="edge"><title>root/tmp/build&#45;&gt;root/tmp/build/repo</title><path fill="none" stroke="#de958e" d="M129.06,-522.04C148.09,-559.92 192.29,-647.92 214.8,-692.73"/><polygon fill="#de958e" stroke="#de958e" points="211.77,-694.49 219.39,-701.85 218.02,-691.35 211.77,-694.49"/></g><!-- root/tmp/build/resources --><g id="node41" class="node"><title>root/tmp/build/resources</title><polygon fill="#343434" stroke="#343434" points="275,-495 184,-495 184,-459 275,-459 275,-495"/><text text-anchor="middle" x="229.5" y="-473.3" font-family="Courier,monospace" font-size="14.00" fill="#de958e">resources</text></g><!-- root/tmp/build&#45;&gt;root/tmp/build/resources --><g id="edge3" class="edge"><title>root/tmp/build&#45;&gt;root/tmp/build/resources</title><path fill="none" stroke="#de958e" d="M148.22,-496.98C156.07,-495.02 164.87,-492.83 173.69,-490.64"/><polygon fill="#de958e" stroke="#de958e" points="174.74,-493.98 183.6,-488.17 173.05,-487.19 174.74,-493.98"/></g><!-- root/tmp/build/repo/LICENSE --><g id="node4" class="node"><title>root/tmp/build/repo/LICENSE</title><polygon fill="#343434" stroke="#343434" points="414,-1008 340,-1008 340,-972 414,-972 414,-1008"/><text text-anchor="middle" x="377" y="-986.3" font-family="Courier,monospace" font-size="14.00" fill="#de958e">LICENSE</text></g><!-- root/tmp/build/repo&#45;&gt;root/tmp/build/repo/LICENSE --><g id="edge4" class="edge"><title>root/tmp/build/repo&#45;&gt;root/tmp/build/repo/LICENSE</title><path fill="none" stroke="#de958e" d="M231.5,-738.11C234.89,-782.27 249.45,-896.73 311,-963 316.44,-968.85 323.34,-973.48 330.6,-977.12"/><polygon fill="#de958e" stroke="#de958e" points="329.35,-980.39 339.91,-981.23 332.17,-973.99 329.35,-980.39"/></g><!-- root/tmp/build/repo/README.md --><g id="node6" class="node"><title>root/tmp/build/repo/README.md</title><polygon fill="#343434" stroke="#343434" points="422.5,-954 331.5,-954 331.5,-918 422.5,-918 422.5,-954"/><text text-anchor="middle" x="377" y="-932.3" font-family="Courier,monospace" font-size="14.00" fill="#de958e">README.md</text></g><!-- root/tmp/build/repo&#45;&gt;root/tmp/ ...

# %%
etl.conform(groups=['base', 'test'])
# !tree /tmp/build
# Out:
# /tmp/build
# ├── repo
# │   ├── LICENSE
# │   ├── README.md
# │   ├── flake8.ini
# │   ├── lunchbox
# │   │   ├── __init__.py
# │   │   ├── enforce.py
# │   │   ├── enforce_test.py
# │   │   ├── singleton.py
# │   │   ├── singleton_test.py
# │   │   ├── stopwatch.py
# │   │   ├── stopwatch_test.py
# │   │   ├── tools.py
# │   │   └── tools_test.py
# │   ├── mypy.ini
# │   ├── pdm.lock
# │   ├── pyproject.toml
# │   ├── pytest.ini
# │   └── tox.ini
# └── resources
#     └── foo.txt
#
# 3 directories, 18 files
